# %% [markdown]
# # 문제풀이

# %% [markdown]
# ## 1단계

# %%
employees = [
    {"name": "Alice", "department": "Sales"},
    {"name": "Bob", "department": "IT"},
    {"name": "Charlie", "department": "HR"}
]

# %%
employees[0]["name"]
# Out:
# 'Alice'

# %%
employees[1]["name"]
# Out:
# 'Bob'

# %% [markdown]
# ## 2단계

# %%
students_info =[
  {"name": "김민수", "age": "20", "major": "컴퓨터공학"},
  {"name": "이영희", "age": "21", "major": "경영학"},
  {"name": "박철수", "age": "22", "major": "디자인"}
]

# %%
books_info =[
  {"title": "파이썬 기초", "author": "홍길동", "price": "25000"},
  {"title": "자료구조", "author": "김철수", "price": "30000"},
  {"title": "알고리즘", "author": "이영희", "price": "28000"}
]

# %%
products_info =[
  {"name": "노트북", "brand": "삼성", "stock": "15"},
  {"name": "마우스", "brand": "로지텍", "stock": "50"},
  {"name": "키보드", "brand": "레오폴드", "stock": "30"}
]

# %%
Staff_info =[
  {"name": "Alice", "department": "Sales", "position": "Manager"},
  {"name": "Bob", "department": "IT", "position": "Engineer"},
  {"name": "Charlie", "department": "HR", "position": "Staff"}
]

# %%
Movie_info =[
  {"title": "인터스텔라", "director": "놀란", "year": "2014"},
  {"title": "기생충", "director": "봉준호", "year": "2019"},
  {"title": "어벤져스", "director": "루소", "year": "2019"}
]

# %%
Cafe_info = [
  {"name": "아메리카노", "size": "Tall", "price": "4500"},
  {"name": "카페라떼", "size": "Grande", "price": "5000"},
  {"name": "카푸치노", "size": "Venti", "price": "5500"}
]

# %%
Car_info = [
  {"model": "소나타", "brand": "현대", "color": "흰색"},
  {"model": "K5", "brand": "기아", "color": "검정"},
  {"model": "SM6", "brand": "르노", "color": "은색"}
]

# %% [markdown]
# ### 문제1

# %%
students = students_info

# %%
students[1]["name"]
# Out:
# '이영희'

# %% [markdown]
# ### 문제2

# %%
books = books_info

# %%
books[0]["author"]
# Out:
# '홍길동'

# %% [markdown]
# ### 문제3

# %%
products = products_info

# %%
products[2]["stock"]
# Out:
# '30'

# %% [markdown]
# ### 문제4

# %%
employees = Staff_info

# %%
employees[1]["department"]
# Out:
# 'IT'

# %% [markdown]
# ### 문제5

# %%
movies = Movie_info

# %%
movies[2]["year"]
# Out:
# '2019'

# %% [markdown]
# ## 3단계

# %%
classes = {
  "1반": ["김민수", "이영희", "박철수"],
  "2반": ["최지영", "정다은", "강민호"],
  "3반": ["윤서준", "한지민"]
}

# %%
fruits = {
  "사과": ["부사", "홍옥", "청송"],
  "배": ["신고", "황금배"],
  "포도": ["샤인머스캣", "MBA", "캠벨"]
}

# %%
departments = {
  "개발팀": ["김코딩", "이파이", "박자바"],
  "디자인팀": ["최포샵", "정피그"],
  "마케팅팀": ["한광고", "윤홍보", "강기획"]
}

# %%
foods = {
  "한식": ["김치찌개", "된장찌개", "불고기"],
  "중식": ["짜장면", "짬뽕", "탕수육"],
  "일식": ["초밥", "라멘", "돈까스"]
}

# %%
courses = {
  "Python": ["Alice", "Bob", "Charlie"],
  "Java": ["David", "Eve"],
  "JavaScript": ["Frank", "Grace", "Henry", "Irene"]
}

# %% [markdown]
# ### 문제1

# %%
classes["2반"][0]
# Out:
# '최지영'

# %% [markdown]
# ### 문제2

# %%
fruits["포도"][2]
# Out:
# '캠벨'

# %% [markdown]
# ### 문제3

# %%
departments["개발팀"]
# Out:
# ['김코딩', '이파이', '박자바']

# %% [markdown]
# ### 문제4

# %%
foods["중식"][1]
# Out:
# '짬뽕'

# %% [markdown]
# ### 문제5

# %%
courses["JavaScript"][3]
# Out:
# 'Irene'

# %% [markdown]
# ## 4단계

# %%
schools = [
  {
    "name": "서울고등학교",
    "classes": {
      "1학년": ["김민수", "이영희"],
      "2학년": ["박철수", "최지영"]
    }
  },
  {
    "name": "부산고등학교",
    "classes": {
      "1학년": ["정다은", "강민호"],
      "2학년": ["윤서준"]
    }
  }
]

# %%
companies = [
  {
    "company": "A Corp",
    "departments": {
      "Sales": ["Alice", "Eve"],
      "IT": ["Bob", "David"]
    }
  },
  {
    "company": "B Corp",
    "departments": {
      "HR": ["Charlie"],
      "Marketing": ["Diana", "Frank"]
    }
  }
]

# %%
malls = [
  {
    "mall": "패션몰",
    "categories": {
      "상의": ["티셔츠", "셔츠", "니트"],
      "하의": ["청바지", "슬랙스"]
    }
  },
  {
    "mall": "전자몰",
    "categories": {
      "컴퓨터": ["노트북", "데스크탑"],
      "주변기기": ["마우스", "키보드", "모니터"]
    }
  }
]

# %%
libraries = [
  {
    "name": "중앙도서관",
    "genres": {
      "소설": ["해리포터", "반지의제왕"],
      "과학": ["코스모스", "이기적유전자"]
    }
  },
  {
    "name": "시립도서관",
    "genres": {
      "역사": ["총균쇠", "사피엔스"],
      "경제": ["국부론", "자본론"]
    }
  }
]

# %%
restaurants = [
  {
    "name": "한식당",
    "menu": {
      "찌개류": ["김치찌개", "된장찌개"],
      "구이류": ["불고기", "삼겹살", "갈비"]
    }
  },
  {
    "name": "중식당",
    "menu": {
      "면류": ["짜장면", "짬뽕"],
      "요리": ["탕수육", "깐풍기"]
    }
  }
]

# %% [markdown]
# ### 문제1

# %%
schools[0]["name"]
# Out:
# '서울고등학교'

# %% [markdown]
# ### 문제2

# %%
companies[0]["departments"]["Sales"]
# Out:
# ['Alice', 'Eve']

# %% [markdown]
# ### 문제3

# %%
malls[1]["categories"]["주변기기"][0]
# Out:
# '마우스'

# %% [markdown]
# ### 문제4

# %%
libraries[1]["genres"]["경제"][1]
# Out:
# '자본론'

# %% [markdown]
# ### 문제5

# %%
restaurants[0]["menu"]["구이류"][2]
# Out:
# '갈비'
