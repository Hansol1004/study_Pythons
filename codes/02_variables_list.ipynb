# %% [markdown]
# ## 단일리스트

# %%
first = ['1', '2', '3', '4']

# %%
first
# Out:
# ['1', '2', '3', '4']

# %%
type(first)
# Out:
# list

# %%
first[2]
# Out:
# '3'

# %%
first[0]
# Out:
# '1'

# %%
second = ['morning',
          'afernoon',
          'night']

# %%
second
# Out:
# ['morning', 'afernoon', 'night']

# %%
second[1]
# Out:
# 'afernoon'

# %%
night = 'night'

# %%
third = ['morning',
          'afernoon',
          night]

# %%
third
# Out:
# ['morning', 'afernoon', 'night']

# %% [markdown]
# ### 문제 1

# %%
fruit1 = "apple"

# %%
fruit2 = "banana"

# %%
fruit3 = "cherry"

# %%
fruits = [fruit1, fruit2, fruit3]

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# ### 문제 2

# %%
colors = ["red", "green", "blue"]

# %%
print(colors[1])
# Out:
# green

# %% [markdown]
# ### 문제 3

# %%
pets = ["dog", "parrot", "fish", "red", "green", "blue"]

# %%
pets[0]
# Out:
# 'dog'

# %%
pets[4]
# Out:
# 'green'
