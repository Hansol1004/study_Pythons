# %%
first = "welcome hansol!"

# %%
first
# Out:
# 'welcome hansol!'

# %%
first = 'good day!'

# %%
first
# Out:
# 'good day!'

# %%
first
# Out:
# "Life is simple 'really?'"

# %%
second
# Out:
# "Life is simple 'really?'"

# %%
first
# Out:
# 'welcome hansol!'

# %%
third = "lift is "+'good'

# %%
third = "life is " + first

# %%
third
# Out:
# 'life is welcome hansol!'

# %%
second = "life is good"

# %%
third = first + "" + second

# %%
third
# Out:
# 'welcome hansol!life is good'

# %% [markdown]
# ## 문제 풀이

# %%
first = "Good"

# %%
second = " Morning"

# %%
result = first + second

# %%
result
# Out:
# 'Good Morning'
