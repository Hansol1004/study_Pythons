# %%
first = { "second" : "good" }

# %%
first
# Out:
# {'second': 'good'}

# %%
first["second"]
# Out:
# 'good'

# %%
second = {
    "first" : "goood",
    "second" : "bad"
}

# %%
second["second"]
# Out:
# 'bad'

# %%
third = "not bad"

# %%
second = {
    "first" : "goood",
    "second" : "bad",
    "not_key" : third
}

# %%
second
# Out:
# {'first': 'goood', 'second': 'bad', 'not_key': 'not bad'}

# %%
second["not_key"]
# Out:
# 'not bad'

# %% [markdown]
# ## 문제풀이

# %% [markdown]
# ### 문제 1

# %%
person = {
    "name" : "Alice",
    "job" : "Engineer"
}

# %%
person
# Out:
# {'name': 'Alice', 'job': 'Engineer'}

# %% [markdown]
# ### 문제 2

# %%
info = {
    "name": "Bob",
    "age": "25",
    "city": "Seoul"
}

# %%
print(info["city"])
# Out:
# Seoul

# %% [markdown]
# ### 문제 3

# %%
info["age"] = "30"
info["name"] = "Charlie"

# %%
info
# Out:
# {'name': 'Charlie', 'age': '30', 'city': 'Seoul'}
